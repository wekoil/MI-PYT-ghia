# %%
import pandas as pd
import explanations
import glob, os

# %%
# nehody = pd.df
for f in glob.glob(os.path.join('', "data/2018/*.csv")):
    try:
        print(f, explanations.file_names[str(f).split('\\')[-1]])
        new_df = pd.read_csv(f, sep=';', encoding='iso-8859-2', index_col=None, error_bad_lines=False)
        new_df.
    except:
        pass
# Out:
# data/2018\00.csv nehody na území hl. m. Prahy
# data/2018\01.csv nehody na území Středočeského kraje
# data/2018\02.csv nehody na území Jihočeského kraje
# data/2018\03.csv nehody na území Plzeňského kraje
# data/2018\04.csv nehody na území Ústeckého kraje
# data/2018\05.csv nehody na území Královéhradeckého kraje
# data/2018\06.csv nehody na území Jihomoravského kraje
# data/2018\07.csv nehody na území Moravskoslezského kraje
# data/2018\14.csv nehody na území Olomouckého kraje
# data/2018\15.csv nehody na území Zlínského kraje
# data/2018\16.csv nehody na území kraje Vysočina
# data/2018\17.csv nehody na území Pardubického kraje
# data/2018\18.csv nehody na území Libereckého kraje
# data/2018\19.csv nehody na území Karlovarského kraje

# %%
data.append('novej')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-3b263522c5c9> in <module>
# ----> 1 data.append('novej')
#
# c:\schule\mi-pyt\__venv__\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7136             ignore_index=ignore_index,
#    7137             verify_integrity=verify_integrity,
# -> 7138             sort=sort,
#    7139         )
#    7140
#
# c:\schule\mi-pyt\__venv__\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     253         verify_integrity=verify_integrity,
#     254         copy=copy,
# --> 255         sort=sort,
#     256     )
#     257
#
# ...

# %%
# data = pd.read_csv('data/2018/00.csv', sep=';', encoding='iso-8859-2', index_col=None, error_bad_lines=False)
nehody = pd.concat(map(lambda file: pd.read_csv(file, delim_whitespace=True), data_files))
nehody = pd.concat(map(pd.read_csv, (glob.glob(os.path.join('', "my_files*.csv")), sep=';', encoding='iso-8859-2', index_col=None, error_bad_lines=False)))
# Out:
#   File "<ipython-input-34-d17ab889370b>", line 3
#     nehody = pd.concat(map(pd.read_csv, (glob.glob(os.path.join('', "my_files*.csv")), sep=';', encoding='iso-8859-2', index_col=None, error_bad_lines=False)))
#                                                                                           ^
# SyntaxError: invalid syntax

# %%
data.columns = explanations.main_columns

# %%
data["druh_pozemni_komunikace"] = data["druh_pozemni_komunikace"].apply(lambda x: explanations.decode_key['druh_pozemni_komunikace'].get(x))

# %%
data.head()
# Out:
#    identifikacni_cislo                            druh_pozemni_komunikace  \
# 0           2100180002       komunikace sledovaná; (ve vybraných městech)
# 1           2100180003  komunikace účelová; ostatní (parkoviště, odpoč...
# 2           2100180004       komunikace sledovaná; (ve vybraných městech)
# 3           2100180005                                  komunikace místní
# 4           2100180006       komunikace sledovaná; (ve vybraných městech)
#
#    cislo_pozemni_komunikace den_mesic_rok  weekday(p2a)  cas  druh_nehody  \
# 0                       NaN    2018-01-01             1   50            3
# 1                       NaN    2018-01-01             1   40            4
# 2                       NaN    2018-01-01             1  114            1
# 3                       NaN    2018-01-01             1  232            3
# 4                       NaN    2018-01-01             1  230            5
#
# ...
